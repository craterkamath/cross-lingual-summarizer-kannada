# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Import the data
import os
PATH = "/home/crater/Desktop/Sem-7/RC/rouge/rouge/"
csv_files = os.listdir(PATH)
dataFrames = {}

for file in csv_files:
    dataFrames[file.split(".")[0]] = pd.read_csv(PATH + file)

# %%
dataFrames['lsa'].head(5)
# Out:
#         file_name    rouge1    rouge2    rougel
# 0  data_51_rec_17  0.150538  0.000000  0.097349
# 1  data_13_rec_21  0.325581  0.163265  0.209235
# 2  data_52_rec_44  0.326087  0.153846  0.194094
# 3   data_7_rec_35  0.089888  0.018182  0.052156
# 4  data_90_rec_11  0.358491  0.132231  0.319845

# %%
dataFrames.keys()
# Out:
# dict_keys(['lsa', 'luhn', 'coRank', 'lex', 'simFusion', 'textRank'])

# %%
# Plots to understand the distribution for each algorithm and different rouges

for file in dataFrames:
    sns.kdeplot(dataFrames[file]["rouge1"], label = file)
plt.legend()
plt.title("Rogue 1 Score Distributions")
plt.show()

# %%
for file in dataFrames:
    sns.kdeplot(dataFrames[file]["rouge2"], label = file)
plt.legend()
plt.title("Rogue 2 Score Distributions")
plt.show()

# %%
for file in dataFrames:
    sns.kdeplot(dataFrames[file]["rougel"], label = file)
plt.legend()
plt.title("Rogue l Score Distributions")
plt.show()

# %%
# Correlation between the coRank and simFusion results
sns.jointplot(x = dataFrames["coRank"]["rouge1"], y = dataFrames["simFusion"]["rouge1"], kind = "kde")
plt.title("Correlation between coRank and simFusion")
plt.show()

# %%
# Correlation between the coRank and simFusion results
sns.jointplot(x = dataFrames["coRank"]["rouge1"], y = dataFrames["simFusion"]["rouge1"])
plt.title("Correlation between coRank and simFusion")
plt.show()

# %%
# Statistical Analysis over the results: We can create a table on these
for file in dataFrames:
    print("Name of the Algorithm:", file)
    print(dataFrames[file].describe())
    print()
# Out:
# Name of the Algorithm: lsa
#             rouge1       rouge2       rougel
# count  6424.000000  6424.000000  6424.000000
# mean      0.179111     0.056160     0.124041
# std       0.128122     0.089900     0.111912
# min       0.000000     0.000000     0.000000
# 25%       0.088496     0.000000     0.049953
# 50%       0.144511     0.018182     0.086588
# 75%       0.233835     0.066667     0.155793
# max       0.780142     0.557576     0.765880
#
# Name of the Algorithm: luhn
#             rouge1       rouge2       rougel
# count  6383.000000  6383.000000  6383.000000
# mean      0.191805     0.062301     0.138486
# std       0.135017     0.094921     0.118393
# min       0.000000     0.000000     0.000000
# 25%       0.095238     0.000000     0.057433
# 50%       0.155844     0.020833     0.100000
# 75%       0.258284     0.085106     0.179143
# max       0.792793     0.658065     0.792664
#
# Name of the Algorithm: coRank
#             rouge1       rouge2       rougel
# count  5330.000000  5330.000000  5330.000000
# mean      0.187961     0.063136     0.131178
# std       0.133647     0.094456     0.120636
# min       0.000000     0.000000     0.000000
# 25%       0.095238     0.000000     0.053004
# 50%       0.152174     0.019231     0.090016
# 75%       0.247122     0.081301     0.163676
# max       0.816327     0.680000     0.815647
#
# Name of the Algorithm: lex
#             rouge1       rouge2       rougel
# count  6391.000000  6391.000000  6391.000000
# mean      0.196429     0.062439     0.142806
# std       0.136403     0.097929     0.119210
# min       0.000000     0.000000     0.000000
# 25%       0.101266     0.000000     0.063084
# 50%       0.161290     0.021505     0.107714
# 75%       0.260000     0.080000     0.181989
# max       0.811321     0.704918     0.791889
#
# Name of the Algorithm: simFusion
#             rouge1       rouge2       rougel
# count  5320.000000  5320.000000  5320.000000
# mean      0.183779     0.060298     0.128286
# std       0.131459     0.093313     0.119051
# min       0.000000     0.000000     0.000000
# 25%       0.093458     0.000000     0.051900
# 50%       0.148936     0.018519     0.088541
# 75%       0.237624     0.074074     0.159788
# max       0.833333     0.693878     0.833333
#
# Name of the Algorithm: textRank
#             rouge1       rouge2       rougel
# count  6349.000000  6349.000000  6349.000000
# mean      0.193113     0.062806     0.135528
# std       0.132882     0.092862     0.116405
# min       0.000000     0.000000     0.000000
# 25%       0.098039     0.000000     0.056113
# 50%       0.158730     0.021053     0.096149
# 75%       0.258065     0.083333     0.175269
# max       0.721311     0.547619     0.700382

# %%
plot_frame = pd.DataFrame(columns=["score", "type", "algo"])

# %%
keys = ["rouge1", "rouge2", "rougel"]
for file in dataFrames:
    for index, row in dataFrames[file].iterrows():
        if index > 100:
            break
        for key in keys:
            plot_frame = plot_frame.append({"score": row[key], "type": key, "algo": file}, ignore_index = True)

# %%
# Summary of the entire analysis
sns.catplot(x = "algo", y = "score", hue = "type", data = plot_frame)
plt.title("All the Information put together!")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-7bf47a45ce23> in <module>()
#       1 # Summary of the entire analysis
# ----> 2 sns.catplot(x = "algo", y = "score", hue = "type", data = plot_frame)
#       3 plt.title("All the Information put together!")
#       4 plt.show()
#
# AttributeError: 'module' object has no attribute 'catplot'

# %%
# !pip install -U seaborn
# Out:
# Collecting seaborn
#   Using cached https://files.pythonhosted.org/packages/a8/76/220ba4420459d9c4c9c9587c6ce607bf56c25b3d3d2de62056efe482dadc/seaborn-0.9.0-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: pandas>=0.15.2 in /home/crater/anaconda3/lib/python3.6/site-packages (from seaborn) (0.20.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.14.0 in /home/crater/anaconda3/lib/python3.6/site-packages (from seaborn) (0.19.0)
# Requirement already satisfied, skipping upgrade: matplotlib>=1.4.3 in /home/crater/anaconda3/lib/python3.6/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.3 in /home/crater/anaconda3/lib/python3.6/site-packages (from seaborn) (1.17.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2 in /home/crater/anaconda3/lib/python3.6/site-packages (from pandas>=0.15.2->seaborn) (2.6.0)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /home/crater/anaconda3/lib/python3.6/site-packages (from pandas>=0.15.2->seaborn) (2017.2)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /home/crater/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4.3->seaborn) (1.10.0)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /home/crater/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4.3->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=1.5.6 in /home/crater/anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4.3->seaborn) (2.1.4)
# Installing collected packages: seaborn
#   Found existing installation: seaborn 0.7.1
# ERROR: Cannot uninstall 'seaborn'. It is a distutils installed project and thus we cannot accurately determine which files belong to it which would lead to only a partial uninstall.
